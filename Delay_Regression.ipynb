# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import os
import joblib
import gc
import warnings
warnings.filterwarnings('ignore')
sb.set()

# %%
directory = r"D:/Ubuntu_Files/Bright_ML_Project/2016"

data_16=pd.DataFrame()

# Iterate over all files in the directory
for filename in os.listdir(directory):
    file_path = os.path.join(directory, filename)
    
    for csv_file_name in os.listdir(file_path):
        csv_file_path=os.path.join(file_path, csv_file_name)
        if os.path.isfile(csv_file_path) and csv_file_name.endswith('.csv'):
            new_data=pd.read_csv(csv_file_path)
            data_16=data_16.append(new_data, ignore_index=True)

columns=data_16.columns
true_col=['FlightDate', 'Quarter', 'Year', 'Month', 'DayofMonth', 'DepTime', 'DepDel15', 'CRSDepTime', 'DepDelayMinutes', 'OriginAirportID', 'DestAirportID', 'ArrTime', 'CRSArrTime', 'ArrDel15', 'ArrDelayMinutes', 'Origin', 'Dest']
drop_col=[]
for i in columns:
    if i not in true_col:
        drop_col.append(i)

data_16.drop(drop_col, axis=1, inplace=True)

true_airports=['ATL', 'CLT', 'DEN', 'DFW', 'EWR', 'IAH', 'JFK', 'LAS', 'LAX', 'MCO', 'MIA', 'ORD', 'PHX', 'SEA', 'SFO']
drop_airports=[]

for i in data_16['Origin'].unique():
    if i not in true_airports:
        drop_airports.append(i)

for i in drop_airports:
    data_16=data_16[data_16['Origin']!=i]
    
drop_airports=[]

for i in data_16['Dest'].unique():
    if i not in true_airports:
        drop_airports.append(i)

for i in drop_airports:
    data_16=data_16[data_16['Dest']!=i]

# %%
directory = r"D:/Ubuntu_Files/Bright_ML_Project/2017"

data_17=pd.DataFrame()

# Iterate over all files in the directory
for filename in os.listdir(directory):
    file_path = os.path.join(directory, filename)
    
    for csv_file_name in os.listdir(file_path):
        csv_file_path=os.path.join(file_path, csv_file_name)
        if os.path.isfile(csv_file_path) and csv_file_name.endswith('.csv'):
            new_data=pd.read_csv(csv_file_path)
            data_17=data_17.append(new_data, ignore_index=True)

columns=data_17.columns
true_col=['FlightDate', 'Quarter', 'Year', 'Month', 'DayofMonth', 'DepTime', 'DepDel15', 'CRSDepTime', 'DepDelayMinutes', 'OriginAirportID', 'DestAirportID', 'ArrTime', 'CRSArrTime', 'ArrDel15', 'ArrDelayMinutes' ,'Origin', 'Dest']
drop_col=[]
for i in columns:
    if i not in true_col:
        drop_col.append(i)

data_17.drop(drop_col, axis=1, inplace=True)

true_airports=['ATL', 'CLT', 'DEN', 'DFW', 'EWR', 'IAH', 'JFK', 'LAS', 'LAX', 'MCO', 'MIA', 'ORD', 'PHX', 'SEA', 'SFO']
drop_airports=[]

for i in data_17['Origin'].unique():
    if i not in true_airports:
        drop_airports.append(i)

for i in drop_airports:
    data_17=data_17[data_17['Origin']!=i]
    
drop_airports=[]

for i in data_17['Dest'].unique():
    if i not in true_airports:
        drop_airports.append(i)

for i in drop_airports:
    data_17=data_17[data_17['Dest']!=i]

# %%
data_16=pd.read_csv(r"C:\Users\Ronak Pahwa\Downloads\data_16.csv")
data_17=pd.read_csv(r"C:\Users\Ronak Pahwa\Downloads\data_17.csv")

# %%
flight_data=pd.DataFrame()

flight_data=flight_data.append(data_16, ignore_index=True)
flight_data=flight_data.append(data_17, ignore_index=True)

flight_data=flight_data.drop(columns=["Unnamed: 0"])

flight_data
# Out:
#          Year  Quarter  Month  DayofMonth  FlightDate  OriginAirportID Origin  \
# 0        2016        1      1           1  2016-01-01            14747    SEA
# 1        2016        1      1           2  2016-01-02            14747    SEA
# 2        2016        1      1           3  2016-01-03            14747    SEA
# 3        2016        1      1           4  2016-01-04            14747    SEA
# 4        2016        1      1           5  2016-01-05            14747    SEA
# ...       ...      ...    ...         ...         ...              ...    ...
# 1877291  2017        3      9          25  2017-09-25            14771    SFO
# 1877292  2017        3      9          25  2017-09-25            11618    EWR
# 1877293  2017        3      9          25  2017-09-25            13204    MCO
# 1877294  2017        3      9          25  2017-09-25            12889    LAS
# 1877295  2017        3      9          25  2017-09-25            13204    MCO
#
#          DestAirportID Dest  CRSDepTime  DepTime  DepDelayMinutes  DepDel15  \
# 0                12478  JFK         745    741.0              0.0       0.0
# 1                12478  JFK         745    737.0              0.0       0.0
# 2                12478  JFK         745    743.0              0.0       0.0
# 3                12478  JFK         745    737.0              0.0       0.0
# 4                12478  JFK         710    708.0              0.0       0.0
# ...                ...  ...         ...      ...              ...       ...
# 1877291          12478  JFK        2045   2038.0              0.0       0.0
# 1877292          13204  MCO        1205   1200.0              0.0       0.0
# 1877293          11618  EWR        1141   1143.0              2.0       0.0
# 1877294          12478  JFK        2159   2157.0              0.0       0.0
# 1877295          12478  JFK         605    605.0              0.0       0.0
#
#          CRSArrTime  ArrTime  ArrDelayMinutes  ArrDel15
# 0              1602   1610.0              8.0       0.0
# 1              1602   1613.0             11.0       0.0
# 2              1602   1547.0              0.0       0.0
# 3              1602   1551.0              0.0       0.0
# 4              1527   1524.0              0.0       0.0
# ...             ...      ...              ...       ...
# 1877291         522    449.0              0.0       0.0
# 1877292        1449   1428.0              0.0       0.0
# 1877293        1417   1409.0              0.0       0.0
# 1877294         557    540.0              0.0       0.0
# 1877295         837    821.0              0.0       0.0
#
# [1877296 rows x 17 columns]

# %%
del data_16
del data_17

gc.collect()
# Out:
# 0

# %%
weather=pd.read_csv(r"C:\Users\Ronak Pahwa\Downloads\weather_raw.csv")

true_col=['windspeedKmph', 'winddirDegree', 'weatherCode', 'precipMM', 'visibility', 'pressure', 'cloudcover', 'DewPointF', 'WindGustKmph', 'tempF', 'WindChillF', 'humidity', 'date', 'time', 'airport' ,'Origin']
del_col=[]

for i in weather.columns:
    if i not in true_col:
        del_col.append(i)
        
weather.drop(del_col, axis=1, inplace=True)
weather
# Out:
#         windspeedKmph  DewPointF  cloudcover  precipMM  pressure  \
# 0                  11         47         100       0.1      1023
# 1                  13         44         100       0.0      1023
# 2                  14         41         100       0.0      1023
# 3                  16         38         100       0.0      1023
# 4                  17         38         100       0.0      1023
# ...               ...        ...         ...       ...       ...
# 263155             26         57           0       0.0      1014
# 263156             26         58           0       0.0      1014
# 263157             26         58           0       0.0      1014
# 263158             23         58           0       0.0      1014
# 263159             20         58           0       0.0      1014
#
#         WindGustKmph  visibility  weatherCode  tempF  WindChillF  \
# 0                 17          10          176     49          46
# 1                 22          10          176     46          42
# 2                 26          10          122     43          38
# 3                 30          10          122     40          33
# 4                 30          10          122     40          33
# ...              ...         ...          ...    ...         ...
# 263155            27          10          113     67          67
# 263156            27          10          113     67          67
# 263157            27          10          113     67          67
# 263158            25          10          113     66          66
# 263159            22          10          113     66          66
#
#         winddirDegree  humidity  time Origin        date
# 0                 318        91     0    ATL  2016-01-01
# 1                 317        92   100    ATL  2016-01-01
# 2                 315        92   200    ATL  2016-01-01
# 3                 314        93   300    ATL  2016-01-01
# 4                 314        93   400    ATL  2016-01-01
# ...               ...       ...   ...    ...         ...
# 263155            296        70  1900    SFO  2017-09-30
# 263156            298        71  2000    SFO  2017-09-30
# 263157            300        73  2100    SFO  2017-09-30
# 263158            302        74  2200    SFO  2017-09-30
# 263159            303        75  2300    SFO  2017-09-30
#
# [263160 rows x 15 columns]

# %%
weather.rename(columns={'time': 'CRSDepTime'}, inplace=True)
weather.rename(columns={'date': 'FlightDate'}, inplace=True)
weather_new=weather.copy()

# %%
del weather

gc.collect()
# Out:
# 0

# %%
def round_time(time):
    hour = time//100
    minute = time%100
    
    if minute >= 30:
        hour += 1
    
    return hour*100

flight_data['CRSDepTime'] = flight_data['CRSDepTime'].apply(round_time)
flight_data['CRSArrTime'] = flight_data['CRSArrTime'].apply(round_time)

flight_data
# Out:
#          Year  Quarter  Month  DayofMonth  FlightDate  OriginAirportID Origin  \
# 0        2016        1      1           1  2016-01-01            14747    SEA
# 1        2016        1      1           2  2016-01-02            14747    SEA
# 2        2016        1      1           3  2016-01-03            14747    SEA
# 3        2016        1      1           4  2016-01-04            14747    SEA
# 4        2016        1      1           5  2016-01-05            14747    SEA
# ...       ...      ...    ...         ...         ...              ...    ...
# 1877291  2017        3      9          25  2017-09-25            14771    SFO
# 1877292  2017        3      9          25  2017-09-25            11618    EWR
# 1877293  2017        3      9          25  2017-09-25            13204    MCO
# 1877294  2017        3      9          25  2017-09-25            12889    LAS
# 1877295  2017        3      9          25  2017-09-25            13204    MCO
#
#          DestAirportID Dest  CRSDepTime  DepTime  DepDelayMinutes  DepDel15  \
# 0                12478  JFK         800    741.0              0.0       0.0
# 1                12478  JFK         800    737.0              0.0       0.0
# 2                12478  JFK         800    743.0              0.0       0.0
# 3                12478  JFK         800    737.0              0.0       0.0
# 4                12478  JFK         700    708.0              0.0       0.0
# ...                ...  ...         ...      ...              ...       ...
# 1877291          12478  JFK        2100   2038.0              0.0       0.0
# 1877292          13204  MCO        1200   1200.0              0.0       0.0
# 1877293          11618  EWR        1200   1143.0              2.0       0.0
# 1877294          12478  JFK        2200   2157.0              0.0       0.0
# 1877295          12478  JFK         600    605.0              0.0       0.0
#
#          CRSArrTime  ArrTime  ArrDelayMinutes  ArrDel15
# 0              1600   1610.0              8.0       0.0
# 1              1600   1613.0             11.0       0.0
# 2              1600   1547.0              0.0       0.0
# 3              1600   1551.0              0.0       0.0
# 4              1500   1524.0              0.0       0.0
# ...             ...      ...              ...       ...
# 1877291         500    449.0              0.0       0.0
# 1877292        1500   1428.0              0.0       0.0
# 1877293        1400   1409.0              0.0       0.0
# 1877294         600    540.0              0.0       0.0
# 1877295         900    821.0              0.0       0.0
#
# [1877296 rows x 17 columns]

# %%
merged_data=pd.merge(flight_data, weather_new, on=['CRSDepTime', 'Origin', 'FlightDate'], how='inner')

# %%
del weather_new
del flight_data

gc.collect()
# Out:
# 0

# %%
merged_data = merged_data.dropna(subset=['DepTime', 'DepDelayMinutes', 'DepDel15', 'ArrDel15', 'ArrTime', 'ArrDelayMinutes'])
merged_data
# Out:
#          Year  Quarter  Month  DayofMonth  FlightDate  OriginAirportID Origin  \
# 0        2016        1      1           1  2016-01-01            14747    SEA
# 1        2016        1      1           1  2016-01-01            14747    SEA
# 2        2016        1      1           1  2016-01-01            14747    SEA
# 3        2016        1      1           1  2016-01-01            14747    SEA
# 4        2016        1      1           1  2016-01-01            14747    SEA
# ...       ...      ...    ...         ...         ...              ...    ...
# 1857882  2017        3      9          23  2017-09-23            12478    JFK
# 1857883  2017        3      9          23  2017-09-23            12478    JFK
# 1857884  2017        3      9          24  2017-09-24            13204    MCO
# 1857885  2017        3      9          24  2017-09-24            12478    JFK
# 1857886  2017        3      9          24  2017-09-24            12478    JFK
#
#          DestAirportID Dest  CRSDepTime  ...  cloudcover  precipMM  pressure  \
# 0                12478  JFK         800  ...           0       0.0      1030
# 1                14107  PHX         800  ...           0       0.0      1030
# 2                11292  DEN         800  ...           0       0.0      1030
# 3                12266  IAH         800  ...           0       0.0      1030
# 4                10397  ATL         800  ...           0       0.0      1030
# ...                ...  ...         ...  ...         ...       ...       ...
# 1857882          13204  MCO        2100  ...           0       0.0      1017
# 1857883          12892  LAX        2200  ...           0       0.0      1017
# 1857884          11618  EWR        2200  ...           5       0.0      1012
# 1857885          12892  LAX        2200  ...          14       0.0      1017
# 1857886          12892  LAX        2300  ...           7       0.0      1017
#
#          WindGustKmph  visibility  weatherCode  tempF  WindChillF  \
# 0                   8          10          113     34          29
# 1                   8          10          113     34          29
# 2                   8          10          113     34          29
# 3                   8          10          113     34          29
# 4                   8          10          113     34          29
# ...               ...         ...          ...    ...         ...
# 1857882            15          10          113     86          86
# 1857883            14          10          113     84          84
# 1857884            15          10          113     81          81
# 1857885            10          10          113     74          74
# 1857886             8          10          113     76          76
#
#          winddirDegree  humidity
# 0                  108        65
# 1                  108        65
# 2                  108        65
# 3                  108        65
# 4                  108        65
# ...                ...       ...
# 1857882              1        55
# 1857883             41        58
# 1857884             44        78
# 1857885            192        87
# 1857886            193        88
#
# [1832252 rows x 29 columns]

# %%
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.ensemble import ExtraTreesRegressor
from lightgbm import LGBMRegressor
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV

# %%
merged_data
# Out:
#          Year  Quarter  Month  DayofMonth  FlightDate  OriginAirportID Origin  \
# 0        2016        1      1           1  2016-01-01            14747    SEA
# 1        2016        1      1           1  2016-01-01            14747    SEA
# 2        2016        1      1           1  2016-01-01            14747    SEA
# 3        2016        1      1           1  2016-01-01            14747    SEA
# 4        2016        1      1           1  2016-01-01            14747    SEA
# ...       ...      ...    ...         ...         ...              ...    ...
# 1857882  2017        3      9          23  2017-09-23            12478    JFK
# 1857883  2017        3      9          23  2017-09-23            12478    JFK
# 1857884  2017        3      9          24  2017-09-24            13204    MCO
# 1857885  2017        3      9          24  2017-09-24            12478    JFK
# 1857886  2017        3      9          24  2017-09-24            12478    JFK
#
#          DestAirportID Dest  CRSDepTime  ...  cloudcover  precipMM  pressure  \
# 0                12478  JFK         800  ...           0       0.0      1030
# 1                14107  PHX         800  ...           0       0.0      1030
# 2                11292  DEN         800  ...           0       0.0      1030
# 3                12266  IAH         800  ...           0       0.0      1030
# 4                10397  ATL         800  ...           0       0.0      1030
# ...                ...  ...         ...  ...         ...       ...       ...
# 1857882          13204  MCO        2100  ...           0       0.0      1017
# 1857883          12892  LAX        2200  ...           0       0.0      1017
# 1857884          11618  EWR        2200  ...           5       0.0      1012
# 1857885          12892  LAX        2200  ...          14       0.0      1017
# 1857886          12892  LAX        2300  ...           7       0.0      1017
#
#          WindGustKmph  visibility  weatherCode  tempF  WindChillF  \
# 0                   8          10          113     34          29
# 1                   8          10          113     34          29
# 2                   8          10          113     34          29
# 3                   8          10          113     34          29
# 4                   8          10          113     34          29
# ...               ...         ...          ...    ...         ...
# 1857882            15          10          113     86          86
# 1857883            14          10          113     84          84
# 1857884            15          10          113     81          81
# 1857885            10          10          113     74          74
# 1857886             8          10          113     76          76
#
#          winddirDegree  humidity
# 0                  108        65
# 1                  108        65
# 2                  108        65
# 3                  108        65
# 4                  108        65
# ...                ...       ...
# 1857882              1        55
# 1857883             41        58
# 1857884             44        78
# 1857885            192        87
# 1857886            193        88
#
# [1832252 rows x 29 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder, PolynomialFeatures
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, r2_score

# %%
merged_data.columns
# Out:
# Index(['Year', 'Quarter', 'Month', 'DayofMonth', 'FlightDate',
#        'OriginAirportID', 'Origin', 'DestAirportID', 'Dest', 'CRSDepTime',
#        'DepTime', 'DepDelayMinutes', 'DepDel15', 'CRSArrTime', 'ArrTime',
#        'ArrDelayMinutes', 'ArrDel15', 'windspeedKmph', 'DewPointF',
#        'cloudcover', 'precipMM', 'pressure', 'WindGustKmph', 'visibility',
#        'weatherCode', 'tempF', 'WindChillF', 'winddirDegree', 'humidity'],
#       dtype='object')

# %%
merged_data=merged_data.drop(['DepTime', 'Origin', 'Dest'], axis=1)

merged_data['flights_per_day'] = merged_data.groupby(['FlightDate', 'OriginAirportID'])['FlightDate'].transform('count')

merged_data['OriginAirportID']=merged_data['OriginAirportID'].astype('object')
merged_data['DestAirportID']=merged_data['DestAirportID'].astype('object')
merged_data['visibility']=merged_data['visibility'].astype('object')
merged_data['weatherCode']=merged_data['weatherCode'].astype('object')

# %%
merged_data.dtypes
# Out:
# Year                 int64
# Quarter              int64
# Month                int64
# DayofMonth           int64
# FlightDate          object
# OriginAirportID     object
# DestAirportID       object
# CRSDepTime           int64
# DepDelayMinutes    float64
# DepDel15           float64
# CRSArrTime           int64
# ArrTime            float64
# ArrDelayMinutes    float64
# ArrDel15           float64
# windspeedKmph        int64
# DewPointF            int64
# cloudcover           int64
# precipMM           float64
# pressure             int64
# WindGustKmph         int64
# visibility          object
# weatherCode         object
# tempF                int64
# WindChillF           int64
# winddirDegree        int64
# humidity             int64
# flights_per_day      int64
# dtype: object

# %%
# Define your features and target variable
features = merged_data.drop(['DepDelayMinutes'], axis=1)
target = merged_data['DepDelayMinutes']

# Split your data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Define preprocessing steps
numeric_features = features.select_dtypes(include=['int64', 'float64']).columns
categorical_features = features.select_dtypes(include=['object']).columns

numeric_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())])

categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %%
# Define the model with GridSearchCV for hyperparameter tuning
model = Pipeline(steps=[('preprocessor', preprocessor),
                        ('regressor', DecisionTreeRegressor())])

# Define the grid of parameters to search over
param_grid = {
    'regressor__max_depth': np.arange(3, 10)
}

# Apply GridSearchCV to the pipeline
grid_search = HalvingGridSearchCV(model, param_grid, cv=5, verbose=2, n_jobs=5,scoring='neg_mean_squared_error')

# Train the model
grid_search.fit(X_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_
print("Best parameters: ", best_params)

# Make predictions on the test data
y_pred = grid_search.predict(X_test)

# Evaluate the model
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error: ", mae)
print("R2 Score: ", r2)
# Out:
# n_iterations: 2
# n_required_iterations: 2
# n_possible_iterations: 2
# min_resources_: 488600
# max_resources_: 1465801
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 7
# n_resources: 488600
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# ----------
# iter: 1
# n_candidates: 3
# n_resources: 1465800
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Best parameters:  {'regressor__max_depth': 8}
# Mean Absolute Error:  3.7455611747753648
# R2 Score:  0.9667444789801616

# %%
joblib.dump(grid_search, r'C:\Users\Ronak Pahwa\Desktop\Bright\dtreg_new_model.joblib')

print("For Training Data:")

# Make predictions on the test data
y_pred_train = grid_search.predict(X_train)

# Evaluate the model
mae_train = mean_absolute_error(y_train, y_pred_train)
r2_train = r2_score(y_train, y_pred_train)
mse_train=mean_squared_error(y_train, y_pred_train)

print("Mean Absolute Error: ", mae_train)
print("R2 Score: ", r2_train)
print("Mean Squared Error: ", mse_train)

print()

print("For Test Data:")

# Make predictions on the test data
y_pred_test = grid_search.predict(X_test)

# Evaluate the model
mae_test = mean_absolute_error(y_test, y_pred_test)
r2_test = r2_score(y_test, y_pred_test)
mse_test=mean_squared_error(y_test, y_pred_test)


print("Mean Absolute Error: ", mae_test)
print("R2 Score: ", r2_test)
print("Mean Squared Error: ", mse_test)
# Out:
# For Training Data:
# Mean Absolute Error:  3.7570175529395686
# R2 Score:  0.9657200900640683
# Mean Squared Error:  58.74287684530909
#
# For Test Data:
# Mean Absolute Error:  3.7455611747753648
# R2 Score:  0.9667444789801616
# Mean Squared Error:  58.95983682116424

# %%
# Define the model
model = Pipeline(steps=[('preprocessor', preprocessor),
                        ('regressor', LinearRegression())])

# Train the model
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['Year', 'Quarter', 'Month', 'DayofMonth', 'CRSDepTime', 'DepDel15',
#        'CRSArrTime', 'ArrTime', 'ArrDelayMinutes', 'ArrDel15', 'windspeedKmph',
#        'DewPointF', 'cloudcover', 'precipMM', 'pressure', 'WindGustKmph',
#        'tempF', 'WindChillF', 'winddirDegree', 'humidity', 'flights_per_day'],
#       dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   Index(['FlightDate', 'OriginAirportID', 'DestAirportID', 'visibility',
#        'weatherCode'],
#       dtype='object'))])),
#                 ('regressor', LinearRegression())])

# %%
joblib.dump(model, r'C:\Users\Ronak Pahwa\Desktop\Bright\linreg_new_model.joblib')

print("For Training Data:")

# Make predictions on the test data
y_pred_train = model.predict(X_train)

# Evaluate the model
mae_train = mean_absolute_error(y_train, y_pred_train)
r2_train = r2_score(y_train, y_pred_train)
mse_train=mean_squared_error(y_train, y_pred_train)

print("Mean Absolute Error: ", mae_train)
print("R2 Score: ", r2_train)
print("Mean Squared Error: ", mse_train)

print()

print("For Test Data:")

# Make predictions on the test data
y_pred_test = model.predict(X_test)

# Evaluate the model
mae_test = mean_absolute_error(y_test, y_pred_test)
r2_test = r2_score(y_test, y_pred_test)
mse_test=mean_squared_error(y_test, y_pred_test)


print("Mean Absolute Error: ", mae_test)
print("R2 Score: ", r2_test)
print("Mean Squared Error: ", mse_test)
# Out:
# For Training Data:
# Mean Absolute Error:  4.479602136167755
# R2 Score:  0.954340931518434
# Mean Squared Error:  78.24247618202718
#
# For Test Data:
# Mean Absolute Error:  4.465573350709151
# R2 Score:  0.9559292542713617
# Mean Squared Error:  78.13451412165452

# %%
# Define the model with GridSearchCV for hyperparameter tuning
model = Pipeline(steps=[('preprocessor', preprocessor),
                        ('regressor', RandomForestRegressor())])

# Define the grid of parameters to search over
param_grid = {
    'regressor__n_estimators': [100, 200],
    'regressor__max_depth': np.arange(5, 15)
}

# Apply GridSearchCV to the pipeline
grid_search = HalvingGridSearchCV(model, param_grid, cv=5, n_jobs=6, verbose=2, scoring='neg_mean_squared_error')

# Train the model
grid_search.fit(X_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_
print("Best parameters: ", best_params)
# Out:
# n_iterations: 3
# n_required_iterations: 3
# n_possible_iterations: 3
# min_resources_: 162866
# max_resources_: 1465801
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 20
# n_resources: 162866
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ----------
# iter: 1
# n_candidates: 7
# n_resources: 488598
# Fitting 5 folds for each of 7 candidates, totalling 35 fits

# %%
joblib.dump(grid_search, r'C:\Users\Ronak Pahwa\Desktop\Bright\rfreg_new_model.joblib')

print("For Training Data:")

# Make predictions on the test data
y_pred_train = grid_search.predict(X_train)

# Evaluate the model
mae_train = mean_absolute_error(y_train, y_pred_train)
r2_train = r2_score(y_train, y_pred_train)
mse_train=mean_squared_error(y_train, y_pred_train)

print("Mean Absolute Error: ", mae_train)
print("R2 Score: ", r2_train)
print("Mean Squared Error: ", mse_train)

print()

print("For Test Data:")

# Make predictions on the test data
y_pred_test = grid_search.predict(X_test)

# Evaluate the model
mae_test = mean_absolute_error(y_test, y_pred_test)
r2_test = r2_score(y_test, y_pred_test)
mse_test=mean_squared_error(y_test, y_pred_test)


print("Mean Absolute Error: ", mae_test)
print("R2 Score: ", r2_test)
print("Mean Squared Error: ", mse_test)

# %%
# Define the model with GridSearchCV for hyperparameter tuning
model = Pipeline(steps=[('preprocessor', preprocessor),
                        ('regressor', XGBRegressor(objective ='reg:squarederror'))])

# Define the grid of parameters to search over
param_grid = {
    'regressor__n_estimators': [100, 200],
    'regressor__learning_rate': [0.01, 0.1],
    'regressor__max_depth': np.arange(3, 15)
}

# Apply GridSearchCV to the pipeline
grid_search = HalvingGridSearchCV(model, param_grid, cv=5, verbose=2, scoring='neg_mean_squared_error')

# Train the model
grid_search.fit(X_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_
print("Best parameters: ", best_params)
# Out:
# n_iterations: 4
# n_required_iterations: 4
# n_possible_iterations: 4
# min_resources_: 54288
# max_resources_: 1465801
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 48
# n_resources: 54288
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=3, regressor__n_estimators=100; total time=   1.1s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=3, regressor__n_estimators=100; total time=   1.0s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=3, regressor__n_estimators=100; total time=   1.1s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=3, regressor__n_estimators=100; total time=   1.0s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=3, regressor__n_estimators=100; total time=   0.9s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=3, regressor__n_estimators=200; total time=   1.8s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=3, regressor__n_estimators=200; total time=   2.0s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=3, regressor__n_estimators=200; total time=   2.1s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=3, regressor__n_estimators=200; total time=   2.0s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=3, regressor__n_estimators=200; total time=   2.1s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=4, regressor__n_estimators=100; total time=   1.3s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=4, regressor__n_estimators=100; total time=   1.3s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=4, regressor__n_estimators=100; total time=   1.3s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=4, regressor__n_estimators=100; total time=   1.2s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=4, regressor__n_estimators=100; total time=   1.2s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=4, regressor__n_estimators=200; total time=   2.1s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=4, regressor__n_estimators=200; total time=   2.2s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=4, regressor__n_estimators=200; total time=   2.3s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=4, regressor__n_estimators=200; total time=   2.7s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=4, regressor__n_estimators=200; total time=   2.7s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100; total time=   1.7s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100; total time=   1.8s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100; total time=   1.8s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100; total time=   1.6s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100; total time=   1.6s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200; total time=   3.1s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200; total time=   3.2s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200; total time=   3.5s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200; total time=   3.2s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200; total time=   3.3s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=100; total time=   2.4s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=100; total time=   2.3s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=100; total time=   2.2s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=100; total time=   2.4s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=100; total time=   2.6s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=200; total time=   4.1s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=200; total time=   4.5s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=200; total time=   4.7s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=200; total time=   4.9s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=200; total time=   4.2s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=100; total time=   2.7s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=100; total time=   2.8s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=100; total time=   2.7s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=100; total time=   2.8s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=100; total time=   2.8s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=200; total time=   5.4s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=200; total time=   5.7s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=200; total time=   5.2s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=200; total time=   5.3s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=200; total time=   5.2s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=8, regressor__n_estimators=100; total time=   3.2s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=8, regressor__n_estimators=100; total time=   3.2s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=8, regressor__n_estimators=100; total time=   3.2s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=8, regressor__n_estimators=100; total time=   3.3s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=8, regressor__n_estimators=100; total time=   3.3s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=8, regressor__n_estimators=200; total time=   6.3s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=8, regressor__n_estimators=200; total time=   6.2s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=8, regressor__n_estimators=200; total time=   6.2s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=8, regressor__n_estimators=200; total time=   6.7s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=8, regressor__n_estimators=200; total time=   6.5s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=9, regressor__n_estimators=100; total time=   4.0s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=9, regressor__n_estimators=100; total time=   3.9s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=9, regressor__n_estimators=100; total time=   3.9s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=9, regressor__n_estimators=100; total time=   4.0s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=9, regressor__n_estimators=100; total time=   4.6s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=9, regressor__n_estimators=200; total time=   7.5s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=9, regressor__n_estimators=200; total time=   7.5s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=9, regressor__n_estimators=200; total time=   7.5s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=9, regressor__n_estimators=200; total time=   8.1s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=9, regressor__n_estimators=200; total time=   7.7s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=100; total time=   4.6s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=100; total time=   4.6s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=100; total time=   4.4s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=100; total time=   4.9s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=100; total time=   4.6s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=200; total time=   8.9s
# [CV] END regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators
3s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=4, regressor__n_estimators=100; total time=   4.3s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=4, regressor__n_estimators=100; total time=   4.3s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=  13.5s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=  13.5s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=  13.5s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=  13.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=  13.6s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200; total time=   9.6s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200; total time=   9.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200; total time=   9.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200; total time=  10.2s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200; total time=   9.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=100; total time=   7.3s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=100; total time=   7.3s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=100; total time=   7.3s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=100; total time=   7.4s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=100; total time=   7.4s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=200; total time=  11.4s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=200; total time=  12.3s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=200; total time=  11.5s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=200; total time=  11.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=200; total time=  11.4s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=100; total time=   6.2s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=100; total time=   6.2s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=100; total time=   6.2s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=100; total time=   6.2s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=100; total time=   6.2s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=100; total time=   5.2s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=100; total time=   5.1s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=100; total time=   5.2s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=100; total time=   5.1s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=100; total time=   5.1s
# ----------
# iter: 2
# n_candidates: 6
# n_resources: 488592
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=8, regressor__n_estimators=200; total time=  54.0s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=8, regressor__n_estimators=200; total time=  53.8s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=8, regressor__n_estimators=200; total time=  54.2s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=8, regressor__n_estimators=200; total time=  54.0s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=8, regressor__n_estimators=200; total time=  54.5s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=100; total time=  25.1s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=100; total time=  25.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=100; total time=  25.0s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=100; total time=  24.4s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=100; total time=  25.1s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=4, regressor__n_estimators=200; total time=  26.3s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=4, regressor__n_estimators=200; total time=  24.8s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=4, regressor__n_estimators=200; total time=  25.3s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=4, regressor__n_estimators=200; total time=  27.6s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=4, regressor__n_estimators=200; total time=  27.0s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=200; total time=  38.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=200; total time=  36.1s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=200; total time=  35.8s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=200; total time=  45.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=200; total time=  37.9s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=  42.0s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=  46.6s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=  45.0s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=  45.2s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=  42.1s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200; total time=  29.8s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200; total time=  30.8s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200; total time=  32.8s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200; total time=  31.0s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200; total time=  29.3s
# ----------
# iter: 3
# n_candidates: 2
# n_resources: 1465776
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time= 3.6min
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time= 3.7min
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time= 3.2min
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time= 3.2min
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time= 3.2min
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=8, regressor__n_estimators=200; total time= 3.6min
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=8, regressor__n_estimators=200; total time= 3.6min
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=8, regressor__n_estimators=200; total time= 3.6min
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=8, regressor__n_estimators=200; total time= 3.7min
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=8, regressor__n_estimators=200; total time= 3.8min
# Best parameters:  {'regressor__learning_rate': 0.1, 'regressor__max_depth': 8, 'regressor__n_estimators': 200}

# %%
joblib.dump(grid_search, r'C:\Users\Ronak Pahwa\Desktop\Bright\xgbreg_new_model.joblib')

print("For Training Data:")

# Make predictions on the test data
y_pred_train = grid_search.predict(X_train)

# Evaluate the model
mae_train = mean_absolute_error(y_train, y_pred_train)
r2_train = r2_score(y_train, y_pred_train)
mse_train=mean_squared_error(y_train, y_pred_train)

print("Mean Absolute Error: ", mae_train)
print("R2 Score: ", r2_train)
print("Mean Squared Error: ", mse_train)

print()

print("For Test Data:")

# Make predictions on the test data
y_pred_test = grid_search.predict(X_test)

# Evaluate the model
mae_test = mean_absolute_error(y_test, y_pred_test)
r2_test = r2_score(y_test, y_pred_test)
mse_test=mean_squared_error(y_test, y_pred_test)


print("Mean Absolute Error: ", mae_test)
print("R2 Score: ", r2_test)
print("Mean Squared Error: ", mse_test)
# Out:
# For Training Data:
# Mean Absolute Error:  3.5168992814794655
# R2 Score:  0.972556000348663
# Mean Squared Error:  47.02869682779936
#
# For Test Data:
# Mean Absolute Error:  3.60573206005413
# R2 Score:  0.9703638543203731
# Mean Squared Error:  52.54292399258126

# %%
model = Pipeline(steps=[('preprocessor', preprocessor),
                        ('regressor', LGBMRegressor())])

# Define the grid of parameters to search over
param_grid = {
    'regressor__n_estimators': [100, 200],
    'regressor__learning_rate': [0.01, 0.1],
    'regressor__max_depth': np.arange(5, 14)
}

# Apply GridSearchCV to the pipeline
grid_search = HalvingGridSearchCV(model, param_grid, cv=5, verbose=2, scoring='neg_mean_squared_error')

# Train the model
grid_search.fit(X_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_
print("Best parameters: ", best_params)
# Out:
# n_iterations: 4
# n_required_iterations: 4
# n_possible_iterations: 4
# min_resources_: 54288
# max_resources_: 1465801
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates:
0s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=13, regressor__n_estimators=200; total time=   1.0s
# ----------
# iter: 1
# n_candidates: 12
# n_resources: 162864
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=12, regressor__n_estimators=100; total time=   1.5s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=12, regressor__n_estimators=100; total time=   1.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=12, regressor__n_estimators=100; total time=   1.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=12, regressor__n_estimators=100; total time=   1.6s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=12, regressor__n_estimators=100; total time=   1.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=200; total time=   2.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=200; total time=   3.2s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=200; total time=   2.8s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=200; total time=   2.3s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=200; total time=   2.5s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=8, regressor__n_estimators=100; total time=   1.5s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=8, regressor__n_estimators=100; total time=   1.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=8, regressor__n_estimators=100; total time=   1.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=8, regressor__n_estimators=100; total time=   1.6s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=8, regressor__n_estimators=100; total time=   1.6s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=9, regressor__n_estimators=100; total time=   1.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=9, regressor__n_estimators=100; total time=   1.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=9, regressor__n_estimators=100; total time=   1.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=9, regressor__n_estimators=100; total time=   1.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=9, regressor__n_estimators=100; total time=   1.8s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200; total time=   2.1s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200; total time=   2.0s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200; total time=   2.1s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200; total time=   1.9s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200; total time=   2.0s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=11, regressor__n_estimators=100; total time=   1.6s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=11, regressor__n_estimators=100; total time=   1.8s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=11, regressor__n_estimators=100; total time=   2.0s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=11, regressor__n_estimators=100; total time=   1.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=11, regressor__n_estimators=100; total time=   1.8s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=200; total time=   2.0s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=200; total time=   2.1s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=200; total time=   2.3s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=200; total time=   2.2s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=200; total time=   2.2s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=100; total time=   1.6s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=100; total time=   1.5s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=100; total time=   1.6s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=100; total time=   1.5s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=100; total time=   1.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=100; total time=   1.8s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=100; total time=   1.8s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=100; total time=   1.8s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=100; total time=   1.9s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=100; total time=   1.8s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=100; total time=   1.5s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=100; total time=   1.5s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=100; total time=   1.6s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=100; total time=   1.5s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=100; total time=   1.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=   2.2s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=   2.5s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=   2.4s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=   2.2s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=   2.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=100; total time=   1.8s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=100; total time=   1.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=100; total time=   1.8s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=100; total time=   1.5s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=100; total time=   1.6s
# ----------
# iter: 2
# n_candidates: 4
# n_resources: 488592
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=200; total time=   5.2s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=200; total time=   4.9s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=200; total time=   5.0s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=200; total time=   5.1s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=6, regressor__n_estimators=200; total time=   5.3s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=   5.3s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=   5.1s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=   5.2s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=   5.4s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=   5.5s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200; total time=   5.4s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200; total time=   6.4s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200; total time=   5.3s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200; total time=   5.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200; total time=   5.4s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=200; total time=   6.0s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=200; total time=   5.3s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=200; total time=   5.4s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=200; total time=   5.4s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=200; total time=   5.5s
# ----------
# iter: 3
# n_candidates: 2
# n_resources: 1465776
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=  14.5s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=  14.9s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=  14.7s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=  16.3s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=200; total time=  14.8s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=200; total time=  15.2s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=200; total time=  15.8s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=200; total time=  14.4s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=200; total time=  14.8s
# [CV] END regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=200; total time=  13.7s
# Best parameters:  {'regressor__learning_rate': 0.1, 'regressor__max_depth': 10, 'regressor__n_estimators': 200}

# %%
joblib.dump(grid_search, r'C:\Users\Ronak Pahwa\Desktop\Bright\lgbmreg_new_model.joblib')

print("For Training Data:")

# Make predictions on the test data
y_pred_train = grid_search.predict(X_train)

# Evaluate the model
mae_train = mean_absolute_error(y_train, y_pred_train)
r2_train = r2_score(y_train, y_pred_train)
mse_train=mean_squared_error(y_train, y_pred_train)

print("Mean Absolute Error: ", mae_train)
print("R2 Score: ", r2_train)
print("Mean Squared Error: ", mse_train)

print()

print("For Test Data:")

# Make predictions on the test data
y_pred_test = grid_search.predict(X_test)

# Evaluate the model
mae_test = mean_absolute_error(y_test, y_pred_test)
r2_test = r2_score(y_test, y_pred_test)
mse_test=mean_squared_error(y_test, y_pred_test)


print("Mean Absolute Error: ", mae_test)
print("R2 Score: ", r2_test)
print("Mean Squared Error: ", mse_test)
# Out:
# For Training Data:
# Mean Absolute Error:  3.651433847510642
# R2 Score:  0.9690637654475185
# Mean Squared Error:  53.01307441502847
#
# For Test Data:
# Mean Absolute Error:  3.67326797022561
# R2 Score:  0.9682490443921601
# Mean Squared Error:  56.2923419674443
